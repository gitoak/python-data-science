# %% [markdown]
# # Project Exploration
# Use this notebook for initial data exploration and prototyping.
#
# **Structure:**
# *   `src/ds/paths.py`: Absolute paths to data folders.
# *   `src/ds/data.py`: Data loaders (e.g. Yahoo Finance).
# *   `src/ds/plots.py`: Plotting style configuration.

# %%
# Standard Imports
import plotly.express as px

# Local Modules (autoreload for development)
# %load_ext autoreload
# %autoreload 2
from ds import data, plots

# Configure Plotting Style
plots.set_style()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Example: Load Data using the project's data connector
# This downloads data to data/raw/ on the first run, then loads from cache.
df = data.get_stock_data("SPY", start="2024-01-01")

print(f"Data shape: {df.shape}")
df.head()
# Out:
# ...
# Saved SPY to /workspaces/python-data-science/data/raw/SPY.csv
# Data shape: (476, 5)
# /workspaces/python-data-science/src/ds/data.py:19: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#                  Close        High         Low        Open     Volume
# Date
# 2024-01-02  462.610413  463.608766  460.496290  462.130830  123623700
# 2024-01-03  458.832367  461.181382  458.225541  460.437516  103585900
# 2024-01-04  457.354431  460.956257  457.129306  458.352754   84232200
# 2024-01-05  457.980865  460.447327  456.522494  457.559976   86118900
# 2024-01-08  464.518951  464.665759  458.352753  458.479996   74879100

# %%
# Example: Plotting
# Using Plotly for interactive charts
fig = px.line(df, y="Close", title="SPY Stock Price (2024)")
fig.show()
